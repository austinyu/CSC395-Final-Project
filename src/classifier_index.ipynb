# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

from data_structs import NewsDataLoader, EvaluationDataLoader, ModelEnum
from utils import model_evaluate, model_predict_evaluate

model_names = ['knn', 'logisticRegression', 'linearSVM', 
               'randomForest', 'voting', 'stack', 'adaBoost'] # TODO: add 'rnn'
model_name2explicit = {
    'knn' : 'K-nearest neighbors (KNN)',
    'logisticRegression' : 'Logistic regression (LR)',
    'linearSVM' : 'Linear SVM (LSVM)',
    'randomForest' : 'Random forest (RF)',
    'voting' : 'Voting classiﬁer (LR, RF, LSVM)',
    'stack' : 'Stacked Classifier',
    'adaBoost' : 'Boosting classiﬁer (AdaBoost)'
}
metrics_names = ['accuracy', 'precision', 'recall', 'f1']

# %%
test_loaders_directory = dict()
score_packages_test_directory = {name : [] for name in model_names}

test_df_5000 = pd.read_csv(f'dataset_modeling/test_5000.csv', index_col=0)
division = int(5000 / 5)
news = test_df_5000.iloc[0 : division, :]

for index in range(1, 5):
    test_df_1000 = test_df_5000.iloc[division * index : division * (index + 1), :]
    test_df_predictors_rnn = test_df_1000['title']
    test_df_predictors = test_df_1000.drop(columns = ['title', 'label'])
    test_df_target = test_df_1000['label']
    test_df_loader = NewsDataLoader(test_df_predictors, test_df_target)
    test_df_loader_rnn = NewsDataLoader(test_df_predictors_rnn, test_df_target)
    test_loaders_directory['test' + str(index)] = (test_df_loader, test_df_loader_rnn)

from sklearn.model_selection import train_test_split
train_news, test_news = train_test_split(news, test_size=0.2)

train_news_predictors_rnn = train_news['title']
train_news_predictors = train_news.drop(columns = ['title', 'label'])
train_news_target = train_news['label']
train_news_loader = NewsDataLoader(train_news_predictors, train_news_target)
train_news_loader_rnn = NewsDataLoader(train_news_predictors_rnn, train_news_target)

test_news_predictors_rnn = test_news['title']
test_news_predictors = test_news.drop(columns = ['title', 'label'])
test_news_target = test_news['label']
test_news_loader = NewsDataLoader(test_news_predictors, test_news_target)
test_news_loader_rnn = NewsDataLoader(test_news_predictors_rnn, test_news_target)

# %%
model_directory = dict()
train_score_packages = {name : None for name in model_names}
test_score_packages = {name : None for name in model_names}

# %% [markdown]
# # Progress
# - KNN [v]
# - Logistic Regression
#   - regularization needed
# - Linear SVM [v]
# - Voting Classifier [x]
# - Stacked Ensemble [v]
# - Random Forest [v]
# - RNN [v]

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

model_knn = KNeighborsClassifier(n_neighbors=200, p=1, weights='distance').fit(
    train_news_loader.predictors, train_news_loader.target)

# %%
score_package_train_knn = model_predict_evaluate(
        model=model_knn, 
        name_model='knn', 
        name_dataset='train',
        news_loader=train_news_loader
)

score_package_test_knn = model_predict_evaluate(
        model=model_knn, 
        name_model='knn', 
        name_dataset='test',
        news_loader=test_news_loader
)

model_directory[ModelEnum.knn] = model_knn
train_score_packages[ModelEnum.knn] = score_package_train_knn
test_score_packages[ModelEnum.knn] = score_package_test_knn
# Out:
# For <knn> evaluated on <train> Dataset:
#     - accuracy: 1.0
#     - precisionn: 1.0
#     - recall: 1.0
#     - f1 score: 1.0
# For <knn> evaluated on <test> Dataset:
#     - accuracy: 0.76
#     - precisionn: 1.0
#     - recall: 0.644
#     - f1 score: 0.757

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

model_logisticRegression = LogisticRegression(solver='liblinear', random_state=0)
model_logisticRegression.fit(
    train_news_loader.predictors, train_news_loader.target)
# Out:
# LogisticRegression(random_state=0, solver='liblinear')

# %%
score_package_train_logisticRegression = model_predict_evaluate(
        model=model_logisticRegression, 
        name_model='logisticRegression', 
        name_dataset='train',
        news_loader=train_news_loader
)

score_package_test_logisticRegression = model_predict_evaluate(
        model=model_logisticRegression, 
        name_model='logisticRegression', 
        name_dataset='test',
        news_loader=test_news_loader
)

model_directory[ModelEnum.logisticRegression] = model_logisticRegression
train_score_packages[ModelEnum.logisticRegression] = score_package_train_logisticRegression
test_score_packages[ModelEnum.logisticRegression] = score_package_test_logisticRegression
# Out:
# For <logisticRegression> evaluated on <train> Dataset:
#     - accuracy: 1.0
#     - precisionn: 1.0
#     - recall: 1.0
#     - f1 score: 1.0
# For <logisticRegression> evaluated on <test> Dataset:
#     - accuracy: 0.905
#     - precisionn: 1.0
#     - recall: 0.821
#     - f1 score: 0.905

# %% [markdown]
# # Linear SVM

# %%
from sklearn import svm

model_svc = svm.SVC(C=0.1, kernel = "linear").fit(train_news_predictors, train_news_target).fit(
    train_news_loader.predictors, train_news_loader.target)

# %%
score_package_train_linearSVN = model_predict_evaluate(
        model=model_svc, 
        name_model='linearSVM', 
        name_dataset='train',
        news_loader=train_news_loader
)

score_package_test_linearSVN = model_predict_evaluate(
        model=model_svc, 
        name_model='linearSVM', 
        name_dataset='test',
        news_loader=test_news_loader
)

model_directory[ModelEnum.linearSVM] = model_svc
train_score_packages[ModelEnum.linearSVM] = score_package_train_linearSVN
test_score_packages[ModelEnum.linearSVM] = score_package_test_linearSVN
# Out:
# For <linearSVM> evaluated on <train> Dataset:
#     - accuracy: 0.975
#     - precisionn: 1.0
#     - recall: 0.945
#     - f1 score: 0.975
# For <linearSVM> evaluated on <test> Dataset:
#     - accuracy: 0.91
#     - precisionn: 1.0
#     - recall: 0.829
#     - f1 score: 0.91

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
model_randomForest = RandomForestClassifier(max_depth=30, min_samples_split=5, 
                                   max_features=20000, n_estimators=100, oob_score=True)

model_randomForest.fit(train_news_loader.predictors, 
                       train_news_loader.target)
# Out:
# RandomForestClassifier(max_depth=30, max_features=20000, min_samples_split=5,
#                        oob_score=True)

# %%
score_package_train_randomForest = model_predict_evaluate(
        model=model_randomForest, 
        name_model='randomForest', 
        name_dataset='train',
        news_loader=train_news_loader
)

score_package_test_randomForest = model_predict_evaluate(
        model=model_randomForest, 
        name_model='randomForest', 
        name_dataset='test',
        news_loader=test_news_loader
)

model_directory[ModelEnum.randomForest] = model_randomForest
train_score_packages[ModelEnum.randomForest] = score_package_train_randomForest
test_score_packages[ModelEnum.randomForest] = score_package_test_randomForest
# Out:
# For <randomForest> evaluated on <train> Dataset:
#     - accuracy: 0.982
#     - precisionn: 1.0
#     - recall: 0.961
#     - f1 score: 0.982
# For <randomForest> evaluated on <test> Dataset:
#     - accuracy: 0.905
#     - precisionn: 0.989
#     - recall: 0.827
#     - f1 score: 0.905

# %% [markdown]
# # Voting Classifier

# %%
from sklearn.ensemble import VotingClassifier

base_estimators = [('logreg', LogisticRegression(solver='liblinear', 
                                                 random_state=0)),
                   ('randomForest', RandomForestClassifier(max_depth=20, 
                                                      min_samples_split=5, 
                                                      max_features=20000, 
                                                      n_estimators=100, 
                                                      oob_score=True)),
                   ('svm', svm.SVC(C=0.1, kernel = "linear"))]

model_voting = VotingClassifier(estimators=base_estimators)
model_voting.fit(train_news_loader.predictors, 
                 train_news_loader.target)
# Out:
# VotingClassifier(estimators=[('logreg',
#                               LogisticRegression(random_state=0,
#                                                  solver='liblinear')),
#                              ('randomForest',
#                               RandomForestClassifier(max_depth=20,
#                                                      max_features=20000,
#                                                      min_samples_split=5,
#                                                      oob_score=True)),
#                              ('svm', SVC(C=0.1, kernel='linear'))])

# %%
score_package_train_voting = model_predict_evaluate(
        model=model_voting, 
        name_model='voting', 
        name_dataset='train',
        news_loader=train_news_loader
)

score_package_test_voting = model_predict_evaluate(
        model=model_voting, 
        name_model='voting', 
        name_dataset='test',
        news_loader=test_news_loader
)


model_directory[ModelEnum.voting] = model_voting
train_score_packages[ModelEnum.voting] = score_package_train_voting
test_score_packages[ModelEnum.voting] = score_package_test_voting
# Out:
# For <voting> evaluated on <train> Dataset:
#     - accuracy: 0.981
#     - precisionn: 1.0
#     - recall: 0.958
#     - f1 score: 0.981
# For <voting> evaluated on <test> Dataset:
#     - accuracy: 0.91
#     - precisionn: 1.0
#     - recall: 0.829
#     - f1 score: 0.91

# %% [markdown]
# # Stacked Generalization

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

## Create list of models in the ensemble
base_models = [('logreg', LogisticRegression(solver='liblinear')),
              ('tree', DecisionTreeClassifier(max_depth=8))]

## Final model used to aggregate predicted probs
my_final_estimator = DecisionTreeClassifier(max_depth=2)

## Create stack
from sklearn.ensemble import StackingClassifier
model_stack = StackingClassifier(estimators = base_models, final_estimator = my_final_estimator, 
                              stack_method ='predict_proba', cv=5)

## Fit and Evaluate (cv is done internally in StackingClassifier)
fitted_stack = model_stack.fit(train_news_loader.predictors, 
                               train_news_loader.target)

# %%
score_package_train_stack = model_predict_evaluate(
        model=model_stack, 
        name_model='stack', 
        name_dataset='train',
        news_loader=train_news_loader
)

score_package_test_stack = model_predict_evaluate(
        model=model_stack, 
        name_model='stack', 
        name_dataset='test',
        news_loader=test_news_loader
)

model_directory[ModelEnum.stack] = model_stack
train_score_packages[ModelEnum.stack] = score_package_train_stack
test_score_packages[ModelEnum.stack] = score_package_test_stack
# Out:
# For <stack> evaluated on <train> Dataset:
#     - accuracy: 1.0
#     - precisionn: 1.0
#     - recall: 1.0
#     - f1 score: 1.0
# For <stack> evaluated on <test> Dataset:
#     - accuracy: 0.91
#     - precisionn: 1.0
#     - recall: 0.829
#     - f1 score: 0.91

# %% [markdown]
# # AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier


model_adaBoost = AdaBoostClassifier(n_estimators=100, 
                                    learning_rate=0.1, 
                                    algorithm = 'SAMME')

model_adaBoost.fit(train_news_loader.predictors, 
                   train_news_loader.target)
# Out:
# AdaBoostClassifier(algorithm='SAMME', learning_rate=0.1, n_estimators=100)

# %%
score_package_train_adaBoost = model_predict_evaluate(
        model=model_adaBoost, 
        name_model='adaBoost', 
        name_dataset='train',
        news_loader=train_news_loader
)

score_package_test_adaBoost = model_predict_evaluate(
        model=model_adaBoost, 
        name_model='adaBoost', 
        name_dataset='test',
        news_loader=test_news_loader
)

model_directory[ModelEnum.adaBoost] = model_adaBoost
train_score_packages[ModelEnum.adaBoost] = score_package_train_adaBoost
test_score_packages[ModelEnum.adaBoost] = score_package_test_adaBoost
# Out:
# For <adaBoost> evaluated on <train> Dataset:
#     - accuracy: 0.9
#     - precisionn: 1.0
#     - recall: 0.812
#     - f1 score: 0.9
# For <adaBoost> evaluated on <test> Dataset:
#     - accuracy: 0.91
#     - precisionn: 1.0
#     - recall: 0.829
#     - f1 score: 0.91

# %% [markdown]
# # RNN

# %%
import torch

# %%
words = [sentence.split(' ') for sentence in train_news_loader_rnn.predictors.to_numpy()] + \
             [sentence.split(' ') for sentence in test_news_loader_rnn.predictors.to_numpy()]
words = np.array([word for sentence in words for word in sentence])
# hashing words for constant time searching
all_words_word2index = {word : index for index, word in enumerate(np.unique(words))}
n_words = len(all_words_word2index)

# %%
# Function to iterate through a sentence of text encode each 
#   letter as a 1 x n_words vector in an #words x 1 x n_words tensor
def sentence2tensor(sentence, all_words_word2index):
    sentence_parsed = sentence.split(' ')
    tensor = torch.zeros(len(sentence_parsed), 1, n_words)
    for index_word, word in enumerate(sentence_parsed):
        tensor[index_word][0][all_words_word2index[word]] = 1
    return tensor

# %%
from torch import nn
class news_cnn(nn.Module):
    ## Constructor commands
    def __init__(self, input_size, hidden_size, output_size):
        super(news_cnn, self).__init__()

        self.hidden_size = hidden_size
        self.i2h = nn.Linear(input_size + hidden_size, hidden_size)
        self.i2o = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)
    
    ## Function to generate predictions
    def forward(self, input, hidden):
        combined = torch.cat((input, hidden), 1)
        hidden = self.i2h(combined)
        output = self.i2o(hidden)
        output = self.softmax(output)
        return output, hidden
    
    def initHidden(self):
        return torch.zeros(1, self.hidden_size)
    
## Function to randomly sample a single example
import random
def randomTrainingExample():
    ## Randomly choose a category index (1 and 0)
    category = random.randint(0, 1)
    
    ## Randomly choose a name in that category
    sentence = train_news_predictors_rnn[train_news_target == category].sample(
                                        n=1).to_numpy()[0]
    ## Convert the chosen example to a tensor
    category_tensor = torch.tensor([category], dtype=torch.long)
    sentence_tensor = sentence2tensor(sentence, all_words_word2index)
    
    return category, sentence, category_tensor, sentence_tensor

# %%
## Set learning rate
learning_rate = 0.005

## Define cost func
cost_fn = nn.CrossEntropyLoss()

## Training function for a single input (name category, name)
def train(model, category_tensor, sentence_tensor):
    
    ## initialize the hidden state
    hidden = model.initHidden()
    
    ## set the gradient to zero
    model.zero_grad()

    ## loop through the letters in the input, getting a prediction and new hidden state each time
    for i in range(sentence_tensor.size()[0]):
        output, hidden = model(sentence_tensor[i], hidden)

    ## Calculate cost and gradients
    cost = cost_fn(output, category_tensor)
    cost.backward()

    # Update parameters
    for p in model.parameters():
        p.data.add_(p.grad.data, alpha = -learning_rate) ## This adds the LR times the gradient to each parameter 

    ## Return the output and cost
    return output, cost.item()

# %%
## Initializations
n_iters = 2000
cost_every_n = 25
current_cost = 0
track_cost = []

news_rnn_inst = news_cnn(n_words, 6000, 2)

### Iteratively update model from randomly chosen example
for iter in range(1, n_iters + 1):
    if (iter % 5 == 0):
        print(f'{iter} iterations completed!')
    category, line, category_tensor, line_tensor = randomTrainingExample()
    output, cost = train(news_rnn_inst, category_tensor, line_tensor)
    current_cost += cost
    
    # Save cost every 25 iterations
    if iter % cost_every_n == 0:
        track_cost.append(current_cost/cost_every_n)
        current_cost = 0
# Out:
# 5 iterations completed!
# 10 iterations completed!
# 15 iterations completed!
# 20 iterations completed!
# 25 iterations completed!
# 30 iterations completed!
# 35 iterations completed!
# 40 iterations completed!
# 45 iterations completed!
# 50 iterations completed!
# 55 iterations completed!
# 60 iterations completed!
# 65 iterations completed!
# 70 iterations completed!
# 75 iterations completed!
# 80 iterations completed!
# 85 iterations completed!
# 90 iterations completed!
# 95 iterations completed!
# 100 iterations completed!
# 105 iterations completed!
# 110 iterations completed!
# 115 iterations completed!
# 120 iterations completed!
# 125 iterations completed!
# 130 iterations completed!
# 135 iterations completed!
# 140 iterations completed!
# 145 iterations completed!
# 150 iterations completed!
# 155 iterations completed!
# 160 iterations completed!
# 165 iterations completed!
# 170 iterations completed!
# 175 iterations completed!
# 180 iterations completed!
# 185 iterations completed!
# 190 iterations completed!
# 195 iterations completed!
# 200 iterations completed!
# 205 iterations completed!
# 210 iterations completed!
# 215 iterations completed!
# 220 iterations completed!
# 225 iterations completed!
# 230 iterations completed!
# 235 iterations completed!
# 240 iterations completed!
# 245 iterations completed!
# 250 iterations completed!
# 255 iterations completed!
# 260 iterations completed!
# 265 iterations completed!
# 270 iterations completed!
# 275 iterations completed!
# 280 iterations completed!
# 285 iterations completed!
# 290 iterations completed!
# 295 iterations completed!
# 300 iterations completed!
# 305 iterations completed!
# 310 iterations completed!
# 315 iterations completed!
# 320 iterations completed!
# 325 iterations completed!
# 330 iterations completed!
# 335 iterations completed!
# 340 iterations completed!
# 345 iterations completed!
# 350 iterations completed!
# 355 iterations completed!
# 360 iterations completed!
# 365 iterations completed!
# 370 iterations completed!
# 375 iterations completed!
# 380 iterations completed!
# 385 iterations completed!
# 390 iterations completed!
# 395 iterations completed!
# 400 iterations completed!
# 405 iterations completed!
# 410 iterations completed!
# 415 iterations completed!
# 420 iterations completed!
# 425 iterations completed!
# 430 iterations completed!
# 435 iterations completed!
# 440 iterations completed!
# 445 iterations completed!
# 450 iterations completed!
# 455 iterations completed!
# 460 iterations completed!
# 465 iterations completed!
# 470 iterations completed!
# 475 iterations completed!
# 480 iterations completed!
# 485 iterations completed!
# 490 iterations completed!
# 495 iterations completed!
# 500 iterations completed!
# 505 iterations completed!
# 510 iterations completed!
# 515 iterations completed!
# 520 iterations completed!
# 525 iterations completed!
# 530 iterations completed!
# 535 iterations completed!
# 540 iterations completed!
# 545 iterations completed!
# 550 iterations completed!
# 555 iterations completed!
# 560 iterations completed!
# 565 iterations completed!
# 570 iterations completed!
# 575 iterations completed!
# 580 iterations completed!
# 585 iterations completed!
# 590 iterations completed!
# 595 iterations completed!
# 600 iterations completed!
# 605 iterations completed!
# 610 iterations completed!
# 615 iterations completed!
# 620 iterations completed!
# 625 iterations completed!
# 630 iterations completed!
# 635 iterations completed!
# 640 iterations completed!
# 645 iterations completed!
# 650 iterations completed!
# 655 iterations completed!
# 660 iterations completed!
# 665 iterations completed!
# 670 iterations completed!
# 675 iterations completed!
# 680 iterations completed!
# 685 iterations completed!
# 690 iterations completed!
# 695 iterations completed!
# 700 iterations completed!
# 705 iterations completed!
# 710 iterations completed!
# 715 iterations completed!
# 720 iterations completed!
# 725 iterations completed!
# 730 iterations completed!
# 735 iterations completed!
# 740 iterations completed!
# 745 iterations completed!
# 750 iterations completed!
# 755 iterations completed!
# 760 iterations completed!
# 765 iterations completed!
# 770 iterations completed!
# 775 iterations completed!
# 780 iterations completed!
# 785 iterations completed!
# 790 iterations completed!
# 795 iterations completed!
# 800 iterations completed!
# 805 iterations completed!
# 810 iterations completed!
# 815 iterations completed!
# 820 iterations completed!
# 825 iterations completed!
# 830 iterations completed!
# 835 iterations completed!
# 840 iterations completed!
# 845 iterations completed!
# 850 iterations completed!
# 855 iterations completed!
# 860 iterations completed!
# 865 iterations completed!
# 870 iterations completed!
# 875 iterations completed!
# 880 iterations completed!
# 885 iterations completed!
# 890 iterations completed!
# 895 iterations completed!
# 900 iterations completed!
# 905 iterations completed!
# 910 iterations completed!
# 915 iterations completed!
# 920 iterations completed!
# 925 iterations completed!
# 930 iterations completed!
# 935 iterations completed!
# 940 iterations completed!
# 945 iterations completed!
# 950 iterations completed!
# 955 iterations completed!
# 960 iterations completed!
# 965 iterations completed!
# 970 iterations completed!
# 975 iterations completed!
# 980 iterations completed!
# 985 iterations completed!
# 990 iterations completed!
# 995 iterations completed!
# 1000 iterations completed!
# 1005 iterations completed!
# 1010 iterations completed!
# 1015 iterations completed!
# 1020 iterations completed!
# 1025 iterations completed!
# 1030 iterations completed!
# 1035 iterations completed!
# 1040 iterations completed!
# 1045 iterations completed!
# 1050 iterations completed!
# 1055 iterations completed!
# 1060 iterations completed!
# 1065 iterations completed!
# 1070 iterations completed!
# 1075 iterations completed!
# 1080 iterations completed!
# 1085 iterations completed!
# 1090 iterations completed!
# 1095 iterations completed!
# 1100 iterations completed!
# 1105 iterations completed!
# 1110 iterations completed!
# 1115 iterations completed!
# 1120 iterations completed!
# 1125 iterations completed!
# 1130 iterations completed!
# 1135 iterations completed!
# 1140 iterations completed!
# 1145 iterations completed!
# 1150 iterations completed!
# 1155 iterations completed!
# 1160 iterations completed!
# 1165 iterations completed!
# 1170 iterations completed!
# 1175 iterations completed!
# 1180 iterations completed!
# 1185 iterations completed!
# 1190 iterations completed!
# 1195 iterations completed!
# 1200 iterations completed!
# 1205 iterations completed!
# 1210 iterations completed!
# 1215 iterations completed!
# 1220 iterations completed!
# 1225 iterations completed!
# 1230 iterations completed!
# 1235 iterations completed!
# 1240 iterations completed!
# 1245 iterations completed!
# 1250 iterations completed!
# 1255 iterations completed!
# 1260 iterations completed!
# 1265 iterations completed!
# 1270 iterations completed!
# 1275 iterations completed!
# 1280 iterations completed!
# 1285 iterations completed!
# 1290 iterations completed!
# 1295 iterations completed!
# 1300 iterations completed!
# 1305 iterations completed!
# 1310 iterations completed!
# 1315 iterations completed!
# 1320 iterations completed!
# 1325 iterations completed!
# 1330 iterations completed!
# 1335 iterations completed!
# 1340 iterations completed!
# 1345 iterations completed!
# 1350 iterations completed!
# 1355 iterations completed!
# 1360 iterations completed!
# 1365 iterations completed!
# 1370 iterations completed!
# 1375 iterations completed!
# 1380 iterations completed!
# 1385 iterations completed!
# 1390 iterations completed!
# 1395 iterations completed!
# 1400 iterations completed!
# 1405 iterations completed!
# 1410 iterations completed!
# 1415 iterations completed!
# 1420 iterations completed!
# 1425 iterations completed!
# 1430 iterations completed!
# 1435 iterations completed!
# 1440 iterations completed!
# 1445 iterations completed!
# 1450 iterations completed!
# 1455 iterations completed!
# 1460 iterations completed!
# 1465 iterations completed!
# 1470 iterations completed!
# 1475 iterations completed!
# 1480 iterations completed!
# 1485 iterations completed!
# 1490 iterations completed!
# 1495 iterations completed!
# 1500 iterations completed!
# 1505 iterations completed!
# 1510 iterations completed!
# 1515 iterations completed!
# 1520 iterations completed!
# 1525 iterations completed!
# 1530 iterations completed!
# 1535 iterations completed!
# 1540 iterations completed!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 14
#      12     print(f'{iter} iterations completed!')
#      13 category, line, category_tensor, line_tensor = randomTrainingExample()
# ---> 14 output, cost = train(news_rnn_inst, category_tensor, line_tensor)
#      15 current_cost += cost
#      17 # Save cost every 25 iterations
#
# Cell In[47], line 22, in train(model, category_tensor, sentence_tensor)
#      20 ## Calculate cost and gradients
#      21 cost = cost_fn(output, category_tensor)
# ---> 22 cost.backward()
#      24 # Update parameters
#      25 for p in model.parameters():
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
plt.plot(track_cost)
plt.show()

# %%
def predict(model, train_news_loader_rnn):    
    ## Don't update gradient with any of these examples
    def __predict(model, sentence):
        with torch.no_grad():
            ## Initialize new hidden state
            hidden = model.initHidden()
            
            ## Convert input str to tensor
            input_t = sentence2tensor(sentence, all_words_word2index)
            ## Pass each character into `rnn`
            for i in range(input_t.size()[0]):
                output, hidden = model(input_t[i], hidden)

            # Get top N categories from output
            _, topi = output.topk(1, 1, True)
            return topi[0][0].item()
    return [__predict(news_rnn_inst, sentence) 
            for sentence in train_news_loader_rnn.predictors]

# %%
# train_news_predictors, train_news_target
 
train_news_target_predicted_rnn = predict(news_rnn_inst, train_news_loader_rnn) 
test_news_target_predicted_rnn = predict(news_rnn_inst, test_news_loader_rnn)

# %%
name_model = 'rnn'
train_evaluation_loader_rnn = EvaluationDataLoader(
        name_dataset='train',
        name_model=name_model,
        target_predicted=train_news_target_predicted_rnn,
        target_actual=train_news_target)
test_evaluation_loader_rnn = EvaluationDataLoader(
    name_dataset='test',
    name_model=name_model,
    target_predicted=test_news_target_predicted_rnn,
    target_actual=test_news_target)

# %%
score_package_train_rnn = model_evaluate(
        evaluation_loader=train_evaluation_loader_rnn, 
        name_dataset='train',
)

score_package_test_rnn = model_evaluate(
        evaluation_loader=test_evaluation_loader_rnn, 
        name_dataset='test',
)

model_directory[ModelEnum.adaBoost] = model_adaBoost
train_score_packages[ModelEnum.adaBoost] = score_package_train_adaBoost
test_score_packages[ModelEnum.adaBoost] = score_package_test_adaBoost

# model_directory[ModelEnum.rnn] = news_rnn_inst
train_score_packages[ModelEnum.rnn] = score_package_train_rnn
test_score_packages[ModelEnum.rnn] = score_package_test_rnn
# Out:
# For <rnn> evaluated on <train> Dataset:
#     - accuracy: 0.902
#     - precisionn: 0.994
#     - recall: 0.82
#     - f1 score: 0.902
# For <rnn> evaluated on <test> Dataset:
#     - accuracy: 0.885
#     - precisionn: 0.988
#     - recall: 0.79
#     - f1 score: 0.885

# %%
model_directory
# Out:
# {'knn': KNeighborsClassifier(n_neighbors=200, p=1, weights='distance'),
#  'logisticRegression': LogisticRegression(random_state=0, solver='liblinear'),
#  'linearSVM': SVC(C=0.1, kernel='linear'),
#  'randomForest': RandomForestClassifier(max_depth=30, max_features=20000, min_samples_split=5,
#                         oob_score=True),
#  'voting': VotingClassifier(estimators=[('logreg',
#                                LogisticRegression(random_state=0,
#                                                   solver='liblinear')),
#                               ('randomForest',
#                                RandomForestClassifier(max_depth=20,
#                                                       max_features=20000,
#                                                       min_samples_split=5,
#                                                       oob_score=True)),
#                               ('svm', SVC(C=0.1, kernel='linear'))]),
#  'stack': StackingClassifier(cv=5,
#                     estimators=[('logreg',
#                                  LogisticRegression(solver='liblinear')),
#                                 ('tree', DecisionTreeClassifier(max_depth=8))],
#                     final_estimator=DecisionTreeClassifier(max_depth=2),
#                     stack_method='predict_proba'),
#  'adaBoost': AdaBoostClassifier(algorithm='SAMME', learning_rate=0.1, n_estimators=100)}

# %%
for model_name, model in model_directory.items():
    for dataset_name, test_tuple in test_loaders_directory.items():
        test_df_loader, _ = test_tuple
        score_package_test_model = model_predict_evaluate(
            model=model, 
            name_model=model_name, 
            name_dataset=dataset_name,
            news_loader=test_df_loader,
            display_confusion=False
        )
        score_packages_test_directory[model_name].append(score_package_test_model)
# Out:
# For <knn> evaluated on <test1> Dataset:
#     - accuracy: 0.795
#     - precisionn: 0.993
#     - recall: 0.671
#     - f1 score: 0.795
# For <knn> evaluated on <test2> Dataset:
#     - accuracy: 0.764
#     - precisionn: 0.998
#     - recall: 0.641
#     - f1 score: 0.763
# For <knn> evaluated on <test3> Dataset:
#     - accuracy: 0.768
#     - precisionn: 0.995
#     - recall: 0.651
#     - f1 score: 0.766
# For <knn> evaluated on <test4> Dataset:
#     - accuracy: 0.771
#     - precisionn: 1.0
#     - recall: 0.647
#     - f1 score: 0.77
# For <logisticRegression> evaluated on <test1> Dataset:
#     - accuracy: 0.912
#     - precisionn: 0.969
#     - recall: 0.843
#     - f1 score: 0.911
# For <logisticRegression> evaluated on <test2> Dataset:
#     - accuracy: 0.894
#     - precisionn: 0.976
#     - recall: 0.811
#     - f1 score: 0.893
# For <logisticRegression> evaluated on <test3> Dataset:
#     - accuracy: 0.898
#     - precisionn: 0.977
#     - recall: 0.821
#     - f1 score: 0.898
# For <logisticRegression> evaluated on <test4> Dataset:
#     - accuracy: 0.894
#     - precisionn: 0.986
#     - recall: 0.805
#     - f1 score: 0.894
# For <linearSVM> evaluated on <test1> Dataset:
#     - accuracy: 0.909
#     - precisionn: 0.978
#     - recall: 0.832
#     - f1 score: 0.908
# For <linearSVM> evaluated on <test2> Dataset:
#     - accuracy: 0.892
#     - precisionn: 0.986
#     - recall: 0.803
#     - f1 score: 0.892
# For <linearSVM> evaluated on <test3> Dataset:
#     - accuracy: 0.9
#     - precisionn: 0.993
#     - recall: 0.815
#     - f1 score: 0.9
# For <linearSVM> evaluated on <test4> Dataset:
#     - accuracy: 0.892
#     - precisionn: 0.995
#     - recall: 0.797
#     - f1 score: 0.892
# For <randomForest> evaluated on <test1> Dataset:
#     - accuracy: 0.916
#     - precisionn: 0.988
#     - recall: 0.838
#     - f1 score: 0.915
# For <randomForest> evaluated on <test2> Dataset:
#     - accuracy: 0.897
#     - precisionn: 0.986
#     - recall: 0.811
#     - f1 score: 0.897
# For <randomForest> evaluated on <test3> Dataset:
#     - accuracy: 0.901
#     - precisionn: 0.986
#     - recall: 0.82
#     - f1 score: 0.901
# For <randomForest> evaluated on <test4> Dataset:
#     - accuracy: 0.894
#     - precisionn: 0.986
#     - recall: 0.805
#     - f1 score: 0.894
# For <voting> evaluated on <test1> Dataset:
#     - accuracy: 0.911
#     - precisionn: 0.981
#     - recall: 0.834
#     - f1 score: 0.91
# For <voting> evaluated on <test2> Dataset:
#     - accuracy: 0.893
#     - precisionn: 0.986
#     - recall: 0.804
#     - f1 score: 0.893
# For <voting> evaluated on <test3> Dataset:
#     - accuracy: 0.902
#     - precisionn: 0.995
#     - recall: 0.817
#     - f1 score: 0.902
# For <voting> evaluated on <test4> Dataset:
#     - accuracy: 0.893
#     - precisionn: 0.995
#     - recall: 0.799
#     - f1 score: 0.893
# For <stack> evaluated on <test1> Dataset:
#     - accuracy: 0.911
#     - precisionn: 0.959
#     - recall: 0.847
#     - f1 score: 0.91
# For <stack> evaluated on <test2> Dataset:
#     - accuracy: 0.899
#     - precisionn: 0.974
#     - recall: 0.82
#     - f1 score: 0.898
# For <stack> evaluated on <test3> Dataset:
#     - accuracy: 0.903
#     - precisionn: 0.968
#     - recall: 0.834
#     - f1 score: 0.903
# For <stack> evaluated on <test4> Dataset:
#     - accuracy: 0.895
#     - precisionn: 0.981
#     - recall: 0.809
#     - f1 score: 0.894
# For <adaBoost> evaluated on <test1> Dataset:
#     - accuracy: 0.914
#     - precisionn: 0.993
#     - recall: 0.832
#     - f1 score: 0.913
# For <adaBoost> evaluated on <test2> Dataset:
#     - accuracy: 0.891
#     - precisionn: 0.993
#     - recall: 0.798
#     - f1 score: 0.891
# For <adaBoost> evaluated on <test3> Dataset:
#     - accuracy: 0.898
#     - precisionn: 0.998
#     - recall: 0.81
#     - f1 score: 0.898
# For <adaBoost> evaluated on <test4> Dataset:
#     - accuracy: 0.888
#     - precisionn: 1.0
#     - recall: 0.789
#     - f1 score: 0.888

# %%
result_comparison = pd.DataFrame(columns='Model DataSet Metrics Value'.split(' '))

# %%
model_names
# Out:
# ['knn',
#  'logisticRegression',
#  'linearSVM',
#  'randomForest',
#  'voting',
#  'stack',
#  'adaBoost']

# %%
for model_name in model_names:
    for metrics in metrics_names:
        for dataset_index in range(4):
            dataset_name = 'DS' + str(dataset_index+1)
            row = {
                'Model' : model_name2explicit.get(model_name),
                'DataSet' : dataset_name,
                'Metrics' : metrics,
                'Value' : score_packages_test_directory[model_name][dataset_index].query_metrics(metrics)
            }
            result_comparison = result_comparison.append(row, ignore_index=True)

# %%
result_comparison.to_csv('./result_comparison/metrics_comparison.csv')

result_comparison
# Out:
#                              Model DataSet    Metrics  Value
# 0        K-nearest neighbors (KNN)     DS1   accuracy  0.795
# 1        K-nearest neighbors (KNN)     DS2   accuracy  0.764
# 2        K-nearest neighbors (KNN)     DS3   accuracy  0.768
# 3        K-nearest neighbors (KNN)     DS4   accuracy  0.771
# 4        K-nearest neighbors (KNN)     DS1  precision  0.993
# ..                             ...     ...        ...    ...
# 107  Boosting classiﬁer (AdaBoost)     DS4     recall  0.789
# 108  Boosting classiﬁer (AdaBoost)     DS1         f1  0.913
# 109  Boosting classiﬁer (AdaBoost)     DS2         f1  0.891
# 110  Boosting classiﬁer (AdaBoost)     DS3         f1  0.898
# 111  Boosting classiﬁer (AdaBoost)     DS4         f1  0.888
#
# [112 rows x 4 columns]
